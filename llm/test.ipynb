# %%
from ollama_client import call_llama

print(call_llama("Explain sales growth in simple business terms"))
# Out:
# Sales growth is a measure of how well a company is doing in terms of selling its products or services. Here's a simple explanation:
#
# **What is sales growth?**
#
# Sales growth measures the increase in revenue (or sales) from one period to another. It shows how much more money a company is making compared to the same time last year, quarter, or month.
#
# **How do you calculate sales growth?**
#
# To calculate sales growth, you need two numbers:
#
# 1. **Base number**: The amount of revenue made in a previous period (e.g., last year). Let's call this "Sales Last Year" = $100,000.
# 2. **New number**: The amount of revenue made in the current period (e.g., this year). Let's call this "Sales This Year" = $120,000.
#
# **Sales Growth Formula:**
#
# Sales Growth (%) = [(Sales This Year - Sales Last Year) / Sales Last Year] x 100
#
# Plugging in our example numbers:
#
# Sales Growth (%) = [($120,000 - $100,000) / $100,000] x 100 = 20%
#
# ...

# %%
#test intent classifier
from intent_classifier import classify_intent

print(classify_intent("Show me total sales by month"))
print(classify_intent("Why did revenue drop last quarter?"))
# Out:
# SQL_QUERY
# FORECAST
